# %% [markdown]
# <a href="https://colab.research.google.com/github/prateekverma145/anime_recommender/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 21.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 461.6/461.6 kB 33.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
# ...

# %%
# !pip install pickle
# Out:
# ERROR: Could not find a version that satisfies the requirement pickle (from versions: none)
# ERROR: No matching distribution found for pickle

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.edge.options import Options

# %%
def fetch_poster(name,id):
    name=name.replace(' ','_')
    url = f"https://myanimelist.net/anime/{id}/{name}/pics"
    # Set up the Selenium WebDriver (make sure you have the appropriate WebDriver installed)
    edge_options = Options()
    edge_options.add_argument('--headless')
    edge_options.add_argument('--disable-gpu')
    edge_options.add_argument('--no-sandbox')
    edge_options.add_argument('--disable-dev-shm-usage')
    driver = webdriver.Edge(options=edge_options)  # You can use other browsers by changing this line

    # Open the webpage
    driver.get(url)

    # Find all image elements using Selenium
    img_elements = driver.find_elements(By.TAG_NAME, 'img')

    # Extract and print the src attribute for each image
    k=0
    l=[]
    for img_element in img_elements:
        k+=1
        src_value = img_element.get_attribute('src')

        if k==2:
           return src_value


    # Close the WebDriver
    driver.quit()

# %%
# !pip install bz2file
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for bz2file: filename=bz2file-0.98-py3-none-any.whl size=6869 sha256=e0786f7fa3afbe3b70b9ef8bf034fede909af8e96e29ac8ff40657d674768a8e
#   Stored in directory: /root/.cache/pip/wheels/69/ee/f7/6fccd10cb65421ba2da64fa6caf8ee7fbae0059884af8c8587
# Successfully built bz2file
# ...

# %%
# !pip install pickle5
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.1/132.1 kB 2.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pickle5: filename=pickle5-0.0.11-cp310-cp310-linux_x86_64.whl size=255318 sha256=2daa7ca430c220d7eef8479c607427d9fb72e0aac30b8b2a6555d78ccf99478a
#   Stored in directory: /root/.cache/pip/wheels/7d/14/ef/4aab19d27fa8e58772be5c71c16add0426acf9e1f64353235c
# Successfully built pickle5
# ...

# %%
import bz2file as bz2

# %%
import pickle5 as pickle

# %%
with bz2.BZ2File('ss.pbz2','r') as f:
  similarity=pickle.load(f)

dictt=pickle.load(open('dict.sav','rb'))

# %%
len(dictt)
# Out:
# {'Kimi no Na wa.': 32281,
#  'Fullmetal Alchemist: Brotherhood': 5114,
#  'Gintama°': 28977,
#  'Steins;Gate': 9253,
#  'Gintama&#039;': 9969,
#  'Haikyuu!!: Karasuno Koukou VS Shiratorizawa Gakuen Koukou': 32935,
#  'Hunter x Hunter (2011)': 11061,
#  'Ginga Eiyuu Densetsu': 820,
#  'Gintama Movie: Kanketsu-hen - Yorozuya yo Eien Nare': 15335,
#  'Gintama&#039;: Enchousen': 15417,
#  'Clannad: After Story': 4181,
#  'Koe no Katachi': 28851,
#  'Gintama': 918,
#  'Code Geass: Hangyaku no Lelouch R2': 2904,
#  'Haikyuu!! Second Season': 28891,
#  'Sen to Chihiro no Kamikakushi': 199,
#  'Shigatsu wa Kimi no Uso': 23273,
#  'Mushishi Zoku Shou 2nd Season': 24701,
#  'Ookami Kodomo no Ame to Yuki': 12355,
#  'Code Geass: Hangyaku no Lelouch': 1575,
#  'Hajime no Ippo': 263,
#  'Rurouni Kenshin: Meiji Kenkaku Romantan - Tsuioku-hen': 44,
#  'Cowboy Bebop': 1,
#  'One Punch Man': 30276,
#  'Mononoke Hime': 164,
#  'Suzumiya Haruhi no Shoushitsu': 7311,
# ...

# %%
l=[]

# %%
l
# Out:
# ['https://cdn.myanimelist.net/images/anime/5/87048.jpg',
#  'https://cdn.myanimelist.net/images/anime/1208/94745.jpg',
#  'https://cdn.myanimelist.net/images/anime/3/72078.jpg',
#  'https://cdn.myanimelist.net/images/anime/1935/127974.jpg',
#  'https://cdn.myanimelist.net/images/anime/4/50361.jpg',
#  'https://cdn.myanimelist.net/images/anime/7/81992.jpg',
#  'https://cdn.myanimelist.net/images/anime/1337/99013.jpg',
#  'https://cdn.myanimelist.net/images/anime/13/13225.jpg',
#  'https://cdn.myanimelist.net/images/anime/10/51723.jpg',
#  'https://cdn.myanimelist.net/images/anime/1452/123686.jpg',
#  'https://cdn.myanimelist.net/images/anime/1299/110774.jpg',
#  'https://cdn.myanimelist.net/images/anime/1122/96435.jpg',
#  'https://cdn.myanimelist.net/images/anime/10/73274.jpg',
#  'https://cdn.myanimelist.net/images/anime/1088/135089.jpg',
#  'https://cdn.myanimelist.net/images/anime/9/76662.jpg',
#  'https://cdn.myanimelist.net/images/anime/6/79597.jpg',
# ...

# %%
len(l)
# Out:
# 301

# %%
l1=[]

# %%
l1
# Out:
# ['https://cdn.myanimelist.net/images/anime/6/68259.jpg',
#  'https://cdn.myanimelist.net/images/anime/5/75639.jpg',
#  'https://cdn.myanimelist.net/images/anime/10/74338.jpg',
#  'https://cdn.myanimelist.net/images/anime/9/73683.jpg',
#  'https://cdn.myanimelist.net/images/anime/13/75194.jpg',
#  'https://cdn.myanimelist.net/images/anime/9/28463.jpg',
#  'https://cdn.myanimelist.net/images/anime/1327/110925.jpg',
#  'https://cdn.myanimelist.net/images/anime/5/26182.jpg',
#  'https://cdn.myanimelist.net/images/anime/6/80899.jpg',
#  'https://cdn.myanimelist.net/images/anime/10/18671.jpg',
#  'https://cdn.myanimelist.net/images/anime/1998/139962.jpg',
#  'https://cdn.myanimelist.net/images/anime/11/65927.jpg',
#  'https://cdn.myanimelist.net/images/anime/5/49993.jpg',
#  'https://cdn.myanimelist.net/images/anime/5/12844.jpg',
#  'https://cdn.myanimelist.net/images/anime/12/34443.jpg',
#  'https://cdn.myanimelist.net/images/anime/3/21835.jpg',
# ...

# %%
len(l1)
# Out:
# 354

# %%
pickle.dump(l3,open("list3,4.sav","wb"))

# %%
l3=[]

# %%
l3
# Out:
# ['https://cdn.myanimelist.net/images/anime/4/75535.jpg',
#  'https://cdn.myanimelist.net/images/anime/4/25808.jpg',
#  'https://cdn.myanimelist.net/images/anime/12/62179.jpg',
#  'https://cdn.myanimelist.net/images/anime/5/17667.jpg',
#  'https://cdn.myanimelist.net/images/anime/12/74683.jpg',
#  'https://cdn.myanimelist.net/images/anime/7/50531.jpg',
#  'https://cdn.myanimelist.net/images/anime/5/73888.jpg',
#  'https://cdn.myanimelist.net/images/anime/12/69457.jpg',
#  'https://cdn.myanimelist.net/images/anime/9/14522.jpg',
#  'https://cdn.myanimelist.net/images/anime/2/79823.jpg',
#  'https://cdn.myanimelist.net/images/anime/13/75587.jpg',
#  'https://cdn.myanimelist.net/images/anime/1599/94412.jpg',
#  'https://cdn.myanimelist.net/images/anime/13/76320.jpg',
#  'https://cdn.myanimelist.net/images/anime/2/73700.jpg',
#  'https://cdn.myanimelist.net/images/anime/10/17471.jpg',
#  'https://cdn.myanimelist.net/images/anime/9/5064.jpg',
# ...

# %%
len(l3)
# Out:
# 851

# %%
655+553
# Out:
# 1208

# %%
k=0
for j in dictt:
  if(k>=1207):
    l3.append(fetch_poster(j,dictt[j]))
    if(k%10==0):
      print(k)
  k+=1
# Out:
# 1210
# 1220
# 1230
# 1240
# 1250
# 1260
# 1270
# 1280
# 1290
# 1300
# 1310
# 1320
# 1330
# 1340
# 1350
# 1360
# 1370
# 1380
# 1390
# 1400
# 1410
# 1420
# 1430
# 1440
# 1450
# 1460
# 1470
# 1480
# 1490
# 1500
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-46-0250c051bbef> in <cell line: 2>()
#       2 for j in dictt:
#       3   if(k>=1207):
# ----> 4     l3.append(fetch_poster(j,dictt[j]))
#       5     if(k%10==0):
#       6       print(k)
#
# <ipython-input-6-986ce4d4e65f> in fetch_poster(name, id)
#      11
#      12     # Open the webpage
# ---> 13     driver.get(url)
#      14
#      15     # Find all image elements using Selenium
#
# /usr/local/lib/python3.10/dist-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     355     def get(self, url: str) -> None:
#     356         """Loads a web page in the current browser session."""
# ...

# %%
c={1:2,2:3}
for i in c:
  print(i)
# Out:
# 1
# 2
